# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import streamlit
import seaborn as sns

# %% [markdown]
# <h3>DATA LOADING :

# %%
# Loading the dataframe
init_df = pd.read_csv(r"C:\Users\PMLS\Desktop\Python\School_Funds_Distribution\data\Input_Schools_Data.csv")

# %%
# How our data looks like
print(init_df.head())
# Out:
#    school_id  emiscode     school_name       district           tehsil  \
# 0      40310  37220028  GES AHMED ABAD         JHELUM  PIND DADAN KHAN
# 1      39291  37130083  GES AHMED ABAD         ATTOCK       PINDI GHEB
# 2       6036  31330090  GES AHMED ABAD  RAHIMYAR KHAN    RAHIMYAR KHAN
# 3      36287  36330251  GES AHMED ABAD         VEHARI           VEHARI
# 4      32931  35610454     GES ALI PUR  NANKANA SAHIB    NANKANA SAHIB
#
#                   markaz             moza  \
# 0           LILLA - MALE        Ahmadabad
# 1       MALHOWALI - MALE       Ahmad Abad
# 2  DARI AZIM KHAN - MALE  Bukhshan Araeen
# 3          SATLUJ - MALE       Ahmad Abad
# 4       WARBURTON - MALE           Alipur
#
#                                    permanent_address      street_name  \
# 0  village post office ahmadabad tehsil pind dada...        Ahmadabad
# 1  Dhoke Ahmed Abad Post Office Malhowali Tehsil ...        Malhowali
# 2  Basti Ahmad Abad moza bukhshan araeen P/O kot ...       Ahmad Abad
# 3                                     moza Ahma Abad       Ahmad Abad
# 4                                    alipur khokhran  Alipur Khokhran
#
#              uc_name  ...  toilets  total_toilets  teachers_toilets  \
# 0          Ahmadabad  ...        1            2.0               1.0
# 1          Malhowali  ...        1            4.0               2.0
# 2  Tibi Gul Muhammad  ...        1            5.0               0.0
# 3        Budh Ghulam  ...        1            6.0               2.0
# 4           Miranpur  ...        1            3.0               1.0
#
#   boundary_wall boundary_wall_state       security care_giver enrollment  \
# 0             1           Completed     Satisfying        0.0      170.0
# 1             1           Completed     Satisfying        0.0       99.0
# 2             1           Completed  Not Available        0.0      127.0
# 3             1           Completed  Not Available        0.0      287.0
# 4             1           Completed     Satisfying        0.0      115.0
#
#   Teachers NonTeachers
# 0     12.0         2.0
# 1     10.0         1.0
# 2      8.0         2.0
# 3     12.0         2.0
# 4      7.0         3.0
#
# [5 rows x 56 columns]

# %%
# shape of our data 
print(init_df.shape)
# Out:
# (48191, 56)

# %%
# shape of our data 
print(init_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48191 entries, 0 to 48190
# Data columns (total 56 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   school_id               48191 non-null  int64
#  1   emiscode                48191 non-null  int64
#  2   school_name             48191 non-null  object
#  3   district                48191 non-null  object
#  4   tehsil                  48191 non-null  object
#  5   markaz                  48191 non-null  object
#  6   moza                    46688 non-null  object
#  7   permanent_address       48190 non-null  object
#  8   street_name             48128 non-null  object
#  9   uc_name                 48190 non-null  object
#  10  uc_no                   48191 non-null  int64
#  11  na_no                   48191 non-null  int64
#  12  pp_no                   48191 non-null  int64
#  13  head_name               48018 non-null  object
#  14  head_type               47992 non-null  object
#  15  head_grade              48018 non-null  float64
#  16  school_status           48191 non-null  object
#  17  medium                  48191 non-null  object
#  18  school_shift            48191 non-null  object
#  19  school_location         48191 non-null  object
#  20  school_gender           48191 non-null  object
#  21  gender_studying         48191 non-null  object
#  22  school_level            48191 non-null  object
#  23  school_type             46682 non-null  object
#  24  est_year                48191 non-null  int64
#  25  upgrade_primary_year    36392 non-null  float64
#  26  upgrade_middle_year     36393 non-null  float64
#  27  upgrade_high_year       36393 non-null  float64
#  28  upgrade_high_sec_year   36392 non-null  float64
#  29  bldg_status             48191 non-null  int64
#  30  school_ownership        47914 non-null  object
#  31  place_status            48191 non-null  int64
#  32  construct_type          47951 non-null  object
#  33  bldg_condition          47951 non-null  object
#  34  total_area_kanal        48191 non-null  int64
#  35  total_area_marla        48190 non-null  float64
#  36  covered_area            48191 non-null  float64
#  37  uncovered_area_kanal    48191 non-null  int64
#  38  uncovered_area_marla    48191 non-null  int64
#  39  functional_classrooms   48191 non-null  int64
#  40  classes                 48191 non-null  int64
#  41  drink_water             48191 non-null  int64
#  42  drink_water_type        48053 non-null  object
#  43  drink_water_type_other  2419 non-null   object
#  44  electricity             48191 non-null  int64
#  45  electricity_source      47415 non-null  object
#  46  toilets                 48191 non-null  int64
#  47  total_toilets           48172 non-null  float64
#  48  teachers_toilets        48172 non-null  float64
#  49  boundary_wall           48191 non-null  int64
#  50  boundary_wall_state     47005 non-null  object
#  51  security                48191 non-null  object
#  52  care_giver              48167 non-null  float64
#  53  enrollment              48189 non-null  float64
#  54  Teachers                48030 non-null  float64
#  55  NonTeachers             23561 non-null  float64
# dtypes: float64(13), int64(17), object(26)
# memory usage: 20.6+ MB
# None

# %%
# looking for null values 
print(init_df.isna().sum())
# Out:
# school_id                     0
# emiscode                      0
# school_name                   0
# district                      0
# tehsil                        0
# markaz                        0
# moza                       1503
# permanent_address             1
# street_name                  63
# uc_name                       1
# uc_no                         0
# na_no                         0
# pp_no                         0
# head_name                   173
# head_type                   199
# head_grade                  173
# school_status                 0
# medium                        0
# school_shift                  0
# school_location               0
# school_gender                 0
# gender_studying               0
# school_level                  0
# school_type                1509
# est_year                      0
# upgrade_primary_year      11799
# upgrade_middle_year       11798
# upgrade_high_year         11798
# upgrade_high_sec_year     11799
# bldg_status                   0
# school_ownership            277
# place_status                  0
# construct_type              240
# bldg_condition              240
# total_area_kanal              0
# total_area_marla              1
# covered_area                  0
# uncovered_area_kanal          0
# uncovered_area_marla          0
# functional_classrooms         0
# classes                       0
# drink_water                   0
# drink_water_type            138
# drink_water_type_other    45772
# electricity                   0
# electricity_source          776
# toilets                       0
# total_toilets                19
# teachers_toilets             19
# boundary_wall                 0
# boundary_wall_state        1186
# security                      0
# care_giver                   24
# enrollment                    2
# Teachers                    161
# NonTeachers               24630
# dtype: int64

# %% [markdown]
# <h3>DATA CLEANING :</h3>
#
# There are alot of columns and not all are relevant to our project , so we will drop and select the ones that adds more value .

# %%
# dropped columns with high number of null values

init_df.drop(['drink_water_type_other','upgrade_primary_year','upgrade_middle_year','upgrade_high_year','upgrade_high_sec_year' ],axis=1,inplace=True)

# %%
# selecting the important features 
features = ['school_id','district','tehsil','est_year','school_gender','gender_studying','bldg_condition','classes','functional_classrooms','enrollment','Teachers','NonTeachers','electricity','drink_water','toilets','teachers_toilets']

# %%
# new dataframe 
df=init_df[features].copy()
df.isna().sum()
# Out:
# school_id                    0
# district                     0
# tehsil                       0
# est_year                     0
# school_gender                0
# gender_studying              0
# bldg_condition             240
# classes                      0
# functional_classrooms        0
# enrollment                   2
# Teachers                   161
# NonTeachers              24630
# electricity                  0
# drink_water                  0
# toilets                      0
# teachers_toilets            19
# dtype: int64

# %%
df['bldg_condition'].fillna('Medium Condition',inplace=True)
df['teachers_toilets'].fillna(0,inplace=True)
df['enrollment'].fillna(np.mean(df['enrollment']),inplace=True)

# %%
df.isna().sum()
# Out:
# school_id                    0
# district                     0
# tehsil                       0
# est_year                     0
# school_gender                0
# gender_studying              0
# bldg_condition               0
# classes                      0
# functional_classrooms        0
# enrollment                   0
# Teachers                   161
# NonTeachers              24630
# electricity                  0
# drink_water                  0
# toilets                      0
# teachers_toilets             0
# dtype: int64

# %%
df.sort_values(by='district', ascending=True,inplace=True)

# %%
df['Teachers'].interpolate('nearest',inplace=True)
df['NonTeachers'].interpolate('nearest',inplace=True)

# %%
df['Teachers'].fillna(np.mean(df['Teachers']),inplace=True)
df['NonTeachers'].fillna(0,inplace=True)

df.isna().sum()
# Out:
# school_id                0
# district                 0
# tehsil                   0
# est_year                 0
# school_gender            0
# gender_studying          0
# bldg_condition           0
# classes                  0
# functional_classrooms    0
# enrollment               0
# Teachers                 0
# NonTeachers              0
# electricity              0
# drink_water              0
# toilets                  0
# teachers_toilets         0
# dtype: int64

# %% [markdown]
# FEATURE ENGINEERING :

# %%
resources=['electricity','drink_water','toilets','teachers_toilets']

def count_missing_resources(row):
  # Count the number of zeros (missing resources) in the resource columns
  return sum(row[resources] == 0)

# Apply the function to each row and add a new 'lack_resource' column
df['lack_resource'] = df.apply(count_missing_resources, axis=1)

# %%
df['lack_resource'].value_counts()
# Out:
# lack_resource
# 0    36159
# 1    11614
# 2      339
# 3       64
# 4       15
# Name: count, dtype: int64

# %%
# determining functional classes ratio of each school 
df["fnl_class_ratio"]=df['functional_classrooms']/df['classes']

# %%
df['bldg_condition'].value_counts()
# Out:
# bldg_condition
# Satisfying                           36119
# Needed Minor Repairing                7999
# Partial Building is Dangerous         1891
# Complete Building Needs Repairing     1485
# Building Is Dangerous                  457
# Medium Condition                       240
# Name: count, dtype: int64

# %%
df['bldg_status_code']=df['bldg_condition'].replace(['Satisfying','Needed Minor Repairing','Medium Condition','Partial Building is Dangerous','Complete Building Needs Repairing','Building Is Dangerous'],[1,1.5,2,2.5,4,5])

# %%
df['fnl_class_ratio'].replace(np.inf,0.0,inplace=True)

# %%
df['fnl_class_ratio'].fillna(0,inplace=True)

# %%
df['fnl_class_ratio'].max(),df['fnl_class_ratio'].min()
# Out:
# (10.2, 0.0)

# %% [markdown]
# <h3>EXPLORATORY DATA ANALYSIS :

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
    
# Calculate the correlation matrix for the numerical columns
corr = df[num_cols].corr()

# Create the heatmap
plt.figure(figsize=(12, 10))
ax = sns.heatmap(corr, cmap='coolwarm')

# Adjust the font size of annotations
ax.tick_params(axis='both', which='major', labelsize=8)

plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
district_counts = df.groupby('district')['school_id'].count()
plt.figure(figsize=(15,7))
# Extract district names and counts for plotting
districts = district_counts.index.to_numpy()  # Get district names as NumPy array
counts = district_counts.to_numpy()  # Get counts as NumPy array
    
    # Create the bar chart
plt.bar(districts, counts)
for i, v in enumerate(counts):
    y_val = v + 0.1  # Add a small offset for better visibility
    plt.text(districts[i], v+0.1, int(v), ha='center', va='bottom', fontsize=9) 
    
    # Add labels and title
plt.xlabel('District')
plt.ylabel('Number of Schools')
plt.xticks(rotation=75)
plt.title('Number of Schools by District')

# Display the plot
plt.show()

# %%
district_counts = df.groupby('district')['enrollment'].sum()

plt.figure(figsize=(15,7))
# Extract district names and counts for plotting
districts = district_counts.index.to_numpy()  # Get district names as NumPy array
counts = district_counts.to_numpy()  # Get counts as NumPy array

# Create the bar chart
plt.bar(districts, counts)
for i, v in enumerate(counts):
        y_val = v + 0.1  # Add a small offset for better visibility
        plt.text(districts[i], v+0.1, int(v), ha='center', va='bottom', fontsize=6.5) 
# Add labels and title
plt.xlabel('District')
plt.ylabel('Number of Enrollments')
plt.xticks(rotation=75)
plt.title('Number of Enrollments by District')

# Display the plotBlockingIOError
plt.show()

# %%
plt.pie(df.groupby("school_gender")["enrollment"].sum(),autopct='%1.1f%%',colors=["blue","orange"])
plt.title('Schools Distribution Based on Genders')
plt.legend(labels=['Female','Male'])
plt.show()

# %%
bldg_cond = df["bldg_condition"].value_counts()
condition=bldg_cond.index.to_numpy()
plt.figure(figsize=(15,7))

counts = bldg_cond.to_numpy()  # Get counts as NumPy array

# # Create the bar chart
plt.barh(condition, counts)
for i, count in enumerate(counts):
        plt.annotate(str(count), xy=(count, condition[i]), ha='left', va='center')
# Add labels and title
plt.xlabel('No of Buidings')
plt.ylabel('Buildings Condition')
plt.title('Distribution of Buildings  Conditions')
plt.grid()

# Display the plotBlockingIOError
plt.show()

# %%
# gender studying in school 
gender_studying = df['gender_studying'].value_counts()
plt.figure(figsize=(8, 6))
gender_studying.plot(kind='bar')

# Add count values on top of the bars
for i, count in enumerate(gender_studying):
    plt.text(i, count, str(count), ha='center', va='bottom')

plt.title("Distribution of Gender Specific Schools")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %%
bldg_cond = df["lack_resource"].value_counts()
condition=bldg_cond.index.to_numpy()
plt.figure(figsize=(15,7))

counts = bldg_cond.to_numpy()  # Get counts as NumPy array

# # Create the bar chart
plt.bar(condition, counts)
for i, v in enumerate(counts):  # Loop through bars and counts
  plt.text(i, v + 0.1, str(v), ha='center', va='bottom', fontsize=12)
# Add labels and title
plt.xlabel('No of Resources')
plt.ylabel('Count of Lackness')
plt.xticks(rotation=75)
plt.title('Distribution of Resource Lackness')
plt.grid()

# Display the plotBlockingIOError
plt.show()

# %% [markdown]
# <h3>FUND ALLOCATION :

# %%
# Funds for combined gender schools 
def both_gender_fund(row):
    if row['gender_studying']=='Both':
        return 6098
    else :
        return 0
        
# funds for building condition       
def calculate_bldg_fund(row):
    if row['bldg_status_code'] == 1.0:
        return 8500
    elif row['bldg_status_code'] == 1.5:
        return 15000     
    elif row['bldg_status_code'] == 2.0:
        return 25000
    elif row['bldg_status_code'] == 2.5:
        return 50237.9
    elif row['bldg_status_code'] == 4.0:
        return 75420
    elif row['bldg_status_code'] == 5.0:
        return 150000
     
# function to allocate resource fund 
def resources_fund(row):
    if row['lack_resource']==0:
        return 0
    elif row['lack_resource']==1:
        return 11957
    elif row['lack_resource']==2:
        return 2*11957
    elif row['lack_resource']==3:
        return 3*11957    
    elif row['lack_resource']==4:
        return 4*11957    

#funds to improve classes functionality
def classes_fund(row):
    if (row['fnl_class_ratio']<=10.2) & (row['fnl_class_ratio']>=0.75):
        return 3069.9
    elif (row['fnl_class_ratio']<0.75) & (row['fnl_class_ratio']>=0.50):
        return 2*3069.9
    elif (row['fnl_class_ratio']<0.50) & (row['fnl_class_ratio']>=0.25):
        return 3*3069.9
    elif (row['fnl_class_ratio']<0.25) & (row['fnl_class_ratio']>=0.0):
        return 4*3069.9    

# funds for old buildings 
def old_bldg_fund(row):
    if row['building_age']>=50:
        return 4274
    elif row['building_age']<50:
        return 0

# %%
df['building_age']=2024-df['est_year']

# %%
# formula for fund distribution 
formula =  (df.apply(old_bldg_fund, axis=1)) +20750 + (df['enrollment']*16.7) + (df['Teachers']*204.1)+(df['NonTeachers']*196)+(df.apply(calculate_bldg_fund, axis=1))+(df.apply(both_gender_fund, axis=1))+(df.apply(resources_fund, axis=1))+(df.apply(classes_fund, axis=1))

# %%
df['bldg_status_code'].value_counts()
# Out:
# bldg_status_code
# 1.0    36119
# 1.5     7999
# 2.5     1891
# 4.0     1485
# 5.0      457
# 2.0      240
# Name: count, dtype: int64

# %%
# final dataframe with funds alloted to schools
df['fund($)']=formula
df
# Out:
#        school_id district      tehsil  est_year school_gender gender_studying  \
# 7737       39127   ATTOCK  FATEH JANG      1976        Female          Female
# 4726       39575   ATTOCK        JAND      1926          Male            Both
# 9219       39129   ATTOCK  FATEH JANG      1976        Female            Both
# 4707       38990   ATTOCK  FATEH JANG      1973          Male            Male
# 20438      39419   ATTOCK  PINDI GHEB      1989        Female            Both
# ...          ...      ...         ...       ...           ...             ...
# 39143      36486   VEHARI      VEHARI      1987          Male            Both
# 39155      35205   VEHARI    BUREWALA      1961          Male            Male
# 39156      35202   VEHARI    BUREWALA      1973          Male            Male
# 35066      35302   VEHARI    BUREWALA      1973          Male            Male
# 11991      36088   VEHARI      VEHARI      1942        Female            Both
#
#                bldg_condition  classes  functional_classrooms  enrollment  \
# 7737               Satisfying        9                      9       177.0
# 4726   Needed Minor Repairing        9                      4       132.0
# 9219               Satisfying        9                      4       115.0
# 4707               Satisfying        9                      5        93.0
# 20438              Satisfying        6                      2        51.0
# ...                       ...      ...                    ...         ...
# 39143              Satisfying        6                      3       157.0
# 39155              Satisfying        6                      4       271.0
# 39156              Satisfying        6                      2       153.0
# 35066              Satisfying        6                      3       242.0
# 11991              Satisfying       11                      8       428.0
#
#        ...  NonTeachers  electricity  drink_water  toilets  teachers_toilets  \
# 7737   ...          2.0            1            1        1               1.0
# 4726   ...          3.0            1            1        1               1.0
# 9219   ...          2.0            1            1        1               0.0
# 4707   ...          2.0            1            1        1               1.0
# 20438  ...          1.0            1            1        1               1.0
# ...    ...          ...          ...          ...      ...               ...
# 39143  ...          1.0            1            1        1               1.0
# 39155  ...          1.0            1            1        1               1.0
# 39156  ...          1.0            1            1        1               1.0
# 35066  ...          1.0            1            1        1               1.0
# 11991  ...          3.0            1            1        1               1.0
#
#        lack_resource  fnl_class_ratio  bldg_status_code  building_age  fund($)
# 7737               0         1.000000               1.0            48  38117.0
# 4726               0         0.444444               1.5            98  59756.9
# 9219               1         0.444444               1.0            48  60868.2
# 4707               0         0.555556               1.0            51  43649.9
# 20438              0         0.333333               1.0            35  46217.7
# ...              ...              ...               ...           ...      ...
# 39143              0         0.500000               1.0            37  45122.1
# 39155              0         0.666667               1.0            63  45406.0
# 39156              0         0.333333               1.0            51  46301.2
# 35066              0         0.500000               1.0            51  45125.8
# 11991              0         0.727273               1.0            82  56967.1
#
# [48191 rows x 21 columns]

# %% [markdown]
#                      ******************************** The End **************************************************
